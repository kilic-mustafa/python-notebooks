# %%
3 + 5
# Out:
# 8

# %%
4+2
# Out:
# 6

# %%
3 * 4
# Out:
# 12

# %% [markdown]
# Numbers

# %%
900 / 4
# Out:
# 225.0

# %%
900 / 7
# Out:
# 128.57142857142858

# %%
10 - 100
# Out:
# -90

# %%
5 * 5 * 5 * 5 * 5
# Out:
# 3125

# %%
5*5*5*5*5*5
# Out:
# 15625

# %%
4+2
# Out:
# 6

# %%
60 / 2
# Out:
# 30.0

# %%
60 * 5
# Out:
# 300

# %%
age = 60

# %%
age
# Out:
# 60

# %%
age * 5
# Out:
# 300

# %%
age / 2
# Out:
# 30.0

# %%
age * 3
# Out:
# 180

# %%
# data type

# %%
type(10)
# Out:
# int

# %%
type(10 * 3)
# Out:
# int

# %%
type(age * 5)
# Out:
# int

# %%
# int -> integer

# %%
type(-1000)
# Out:
# int

# %%
x = -10

# %%
type(x)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %%
# float -> floating point

# %%
pi = 3.14

# %%
pi * 2
# Out:
# 6.28

# %%
x
# Out:
# -10

# %%
x + pi
# Out:
# -6.859999999999999

# %%
x / pi
# Out:
# -3.184713375796178

# %%
x = 50

# %%
x
# Out:
# 50

# %%
x = 1000

# %%
x
# Out:
# 1000

# %%
myFloat = 1.323434

# %%
type(myFloat)
# Out:
# float

# %%
# camelCase
# snake_case

# %%
40 / 10
# Out:
# 4.0

# %%
type(40 / 10)
# Out:
# float

# %%
40 / 13
# Out:
# 3.076923076923077

# %%
4 / 2
# Out:
# 2.0

# %%
4 / 3
# Out:
# 1.3333333333333333

# %%
4.0 / 3.0
# Out:
# 1.3333333333333333

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
4 * 2
# Out:
# 8

# %%
4 + 2
# Out:
# 6

# %%
4 - 2
# Out:
# 2

# %%
4.0 - 2
# Out:
# 2.0

# %%
4.4 - 2
# Out:
# 2.4000000000000004

# %%
4.3 - 2
# Out:
# 2.3

# %%
4.2 - 1
# Out:
# 3.2

# %%
4.1 - 1
# Out:
# 3.0999999999999996

# %%
4.5 - 2
# Out:
# 2.5

# %%
type(4.5 - 2)
# Out:
# float

# %%
4.2 * 3
# Out:
# 12.600000000000001

# %%
4.2 * 3.2
# Out:
# 13.440000000000001

# %%
4.2 * 3 - 10
# Out:
# 2.6000000000000014

# %%
2 - 10 * 2
# Out:
# -18

# %%
2 * 2 * 2 * 2 * 2
# Out:
# 32

# %%
2 ** 5 # power
# Out:
# 32

# %%
2 ** 9
# Out:
# 512

# %%
10 % 3 # remainder
# Out:
# 1

# %%
10 % 2
# Out:
# 0

# %%
10 % 4
# Out:
# 2

# %%
30 // 3
# Out:
# 10

# %%
30 // 7
# Out:
# 4
